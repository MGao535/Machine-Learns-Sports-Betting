# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
# data1 = "../Data/nfl odds 2007-08.csv"
# data2 = "../Data/nfl odds 2008-09.csv"
# data3 = "../Data/nfl odds 2009-10.csv"
# data4 = "../Data/nfl odds 2010-11.csv"
# data5 = "../Data/nfl odds 2011-12.csv"
# data6 = "../Data/nfl odds 2012-13.csv"
# data7 = "../Data/nfl odds 2013-14.csv"
# data8 = "../Data/nfl odds 2014-15.csv"
# data9 = "../Data/nfl odds 2015-16.csv"

new_data = "../Data/spreadspoke_scores.csv"


# Read the nfl data
# data1 = pd.read_csv(data1)
# data2 = pd.read_csv(data2)
# data3 = pd.read_csv(data3)
# data4 = pd.read_csv(data4)
# data5 = pd.read_csv(data5)
# data6 = pd.read_csv(data6)
# data7 = pd.read_csv(data7)
# data8 = pd.read_csv(data8)
# data9 = pd.read_csv(data9)
new_data = pd.read_csv(new_data)

# %%
# data1
new_data
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0       09/06/2007             2007             1             False
# 1       09/09/2007             2007             1             False
# 2       09/09/2007             2007             1             False
# 3       09/09/2007             2007             1             False
# 4       09/09/2007             2007             1             False
# ...            ...              ...           ...               ...
# 2387    01/03/2016             2015            17             False
# 2388    01/03/2016             2015            17             False
# 2389    01/03/2016             2015            17             False
# 2390    01/03/2016             2015            17             False
# 2391    01/03/2016             2015            17             False
#
#                 team_home  score_home  score_away             team_away  \
# 0      Indianapolis Colts          41          10    New Orleans Saints
# 1           Buffalo Bills          14          15        Denver Broncos
# 2        Cleveland Browns           7          34   Pittsburgh Steelers
# 3          Dallas Cowboys          45          35       New York Giants
# 4       Green Bay Packers          16          13   Philadelphia Eagles
# ...                   ...         ...         ...                   ...
# 2387   Indianapolis Colts          30          24      Tennessee Titans
# 2388   Kansas City Chiefs          23          17       Oakland Raiders
# 2389       Miami Dolphins          20          10  New England Patriots
# 2390      New York Giants          30          35   Philadelphia Eagles
# 2391  San Francisco 49ers          19          16        St. Louis Rams
#
#      team_favorite_id  spread_favorite  over_under_line               stadium  \
# 0                 IND             -5.5             53.5              RCA Dome
# 1                 DEN             -3.0             37.0  Ralph Wilson Stadium
# 2                 PIT             -4.5             36.5   FirstEnergy Stadium
# 3                 DAL             -6.5             44.5         Texas Stadium
# 4                 PHI             -3.0             42.5         Lambeau Field
# ...               ...              ...              ...                   ...
# 2387              IND             -4.0             39.0     Lucas Oil Stadium
# 2388               KC             -6.5             43.5     Arrowhead Stadium
# 2389               NE            -10.0             46.5      Sun Life Stadium
# 2390              NYG             -3.5             51.0       MetLife Stadium
# 2391              LAR             -3.0             38.5        Levi's Stadium
#
#       stadium_neutral  weather_temperature  weather_wind_mph  \
# 0               False                 72.0               0.0
# 1               False                 67.0               9.0
# 2               False                 71.0               8.0
# 3               False                 85.0              10.0
# 4               False                 63.0               8.0
# ...               ...                  ...               ...
# 2387            False                 72.0               0.0
# 2388            False                 32.0               7.0
# 2389            False                 78.0               4.0
# 2390            False                 44.0              10.0
# 2391            False                 57.0               0.0
#
#       weather_humidity weather_detail
# 0                  NaN           DOME
# 1                 80.0            NaN
# 2                 83.0            NaN
# 3                 66.0            NaN
# 4                 78.0            NaN
# ...                ...            ...
# 2387               NaN           DOME
# 2388               NaN            NaN
# 2389               NaN            NaN
# 2390               NaN            NaN
# 2391               NaN            NaN
#
# [2392 rows x 17 columns]

# %%
# data1_reg = data1.drop(data1.index[512:534])
# data1_reg = data1_reg.reset_index(drop=True)
# data1_reg
new_data.drop(new_data[new_data.schedule_playoff == True].index, inplace=True)
new_data
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0       09/06/2007             2007             1             False
# 1       09/09/2007             2007             1             False
# 2       09/09/2007             2007             1             False
# 3       09/09/2007             2007             1             False
# 4       09/09/2007             2007             1             False
# ...            ...              ...           ...               ...
# 2387    01/03/2016             2015            17             False
# 2388    01/03/2016             2015            17             False
# 2389    01/03/2016             2015            17             False
# 2390    01/03/2016             2015            17             False
# 2391    01/03/2016             2015            17             False
#
#                 team_home  score_home  score_away             team_away  \
# 0      Indianapolis Colts          41          10    New Orleans Saints
# 1           Buffalo Bills          14          15        Denver Broncos
# 2        Cleveland Browns           7          34   Pittsburgh Steelers
# 3          Dallas Cowboys          45          35       New York Giants
# 4       Green Bay Packers          16          13   Philadelphia Eagles
# ...                   ...         ...         ...                   ...
# 2387   Indianapolis Colts          30          24      Tennessee Titans
# 2388   Kansas City Chiefs          23          17       Oakland Raiders
# 2389       Miami Dolphins          20          10  New England Patriots
# 2390      New York Giants          30          35   Philadelphia Eagles
# 2391  San Francisco 49ers          19          16        St. Louis Rams
#
#      team_favorite_id  spread_favorite  over_under_line               stadium  \
# 0                 IND             -5.5             53.5              RCA Dome
# 1                 DEN             -3.0             37.0  Ralph Wilson Stadium
# 2                 PIT             -4.5             36.5   FirstEnergy Stadium
# 3                 DAL             -6.5             44.5         Texas Stadium
# 4                 PHI             -3.0             42.5         Lambeau Field
# ...               ...              ...              ...                   ...
# 2387              IND             -4.0             39.0     Lucas Oil Stadium
# 2388               KC             -6.5             43.5     Arrowhead Stadium
# 2389               NE            -10.0             46.5      Sun Life Stadium
# 2390              NYG             -3.5             51.0       MetLife Stadium
# 2391              LAR             -3.0             38.5        Levi's Stadium
#
#       stadium_neutral  weather_temperature  weather_wind_mph  \
# 0               False                 72.0               0.0
# 1               False                 67.0               9.0
# 2               False                 71.0               8.0
# 3               False                 85.0              10.0
# 4               False                 63.0               8.0
# ...               ...                  ...               ...
# 2387            False                 72.0               0.0
# 2388            False                 32.0               7.0
# 2389            False                 78.0               4.0
# 2390            False                 44.0              10.0
# 2391            False                 57.0               0.0
#
#       weather_humidity weather_detail
# 0                  NaN           DOME
# 1                 80.0            NaN
# 2                 83.0            NaN
# 3                 66.0            NaN
# 4                 78.0            NaN
# ...                ...            ...
# 2387               NaN           DOME
# 2388               NaN            NaN
# 2389               NaN            NaN
# 2390               NaN            NaN
# 2391               NaN            NaN
#
# [2304 rows x 17 columns]

# %%
# data1['Season Start']='2007'
# data2['Season Start']='2008'
# data3['Season Start']='2009'
# data4['Season Start']='2010'
# data5['Season Start']='2011'
# data6['Season Start']='2012'
# data7['Season Start']='2013'
# data8['Season Start']='2014'
# data9['Season Start']='2015'

# data1
new_data.dtypes
# Out:
# schedule_date           object
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home               int64
# score_away               int64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line        float64
# stadium                 object
# stadium_neutral           bool
# weather_temperature    float64
# weather_wind_mph       float64
# weather_humidity       float64
# weather_detail          object
# dtype: object

# %%
# #put the frames of the different seasons into a list
# frames = [data1, data2, data3, data4, data5, data6, data7, data8, data9]

# #stack the frames into a single set for analysis
# df = pd.concat(frames)
# df.head()

# %%
# p_dif = []

# for i in range(1, df.shape[0], 2):
#         home_dif = df['Final'].iloc[i] - df['Final'].iloc[i-1]
#         away_dif = df['Final'].iloc[i-1] - df['Final'].iloc[i]
#         p_dif.append(away_dif)
#         p_dif.append(home_dif)
        
# df['Point_Dif'] = p_dif
# columns = ['VH', 'Team', 'Final', 'Close', 'Point_Dif']
# p_dif_df = df[columns]
# p_dif_df.head()
